# %%
import pandas as pd
df=pd.read_csv('http://bit.ly/2JNCRvx')
df.head()
# Out:
#    article_id  store_id  current_selling_price  cost_price  \
# 0           2         2                    9.8    8.773753
# 1           2         3                    9.8    8.512627
# 2           2         4                    9.8    8.484649
# 3           2         5                    9.8    8.354969
# 4           3         2                   19.6   17.794164
#
#                                  name
# 0  top ramen masala noodles 70g rs.10
# 1  top ramen masala noodles 70g rs.10
# 2  top ramen masala noodles 70g rs.10
# 3  top ramen masala noodles 70g rs.10
# 4       top ramen masala noodles 140g

# %%
df1=pd.read_csv('http://bit.ly/2JNCRvx')
df.head()
# Out:
#    article_id  store_id  current_selling_price  cost_price  \
# 0           2         2                    9.8    8.773753
# 1           2         3                    9.8    8.512627
# 2           2         4                    9.8    8.484649
# 3           2         5                    9.8    8.354969
# 4           3         2                   19.6   17.794164
#
#                                  name
# 0  top ramen masala noodles 70g rs.10
# 1  top ramen masala noodles 70g rs.10
# 2  top ramen masala noodles 70g rs.10
# 3  top ramen masala noodles 70g rs.10
# 4       top ramen masala noodles 140g
